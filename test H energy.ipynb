# %%
import requests

date = '2022-10-01'
API_KEY = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJpOHR2S1FCeEdnNWl2R3VyclVaNU5tIiwiaWF0IjoxNjY3NjQ4MTYyLCJleHAiOjE2Njg3ODM2MDAsInR5cGUiOiJhcGlfa2V5In0.oyQ7W5utmLUK9dzhqHJSi7HTwjJJCs6CYQ9LMzYa4YU'
weathers_1 = requests.get(f'https://research-api.dershare.xyz/open-proc/cmpt-2022/weathers/1/observeds/{date}', headers={
                            'Authorization': f'Bearer {API_KEY}'
                        }).json()
print(weathers_1)
# Out:
# [{'id': 1, 'time': '2022-09-30T15:58:00+00:00', 'temperature': 17.1, 'humidity': 84.0, 'dew_point': 14.5, 'wind_dir': 338.0, 'wind_spd': 2.7, 'uv_idx': 0.0, 'visibility': 8.0, 'cloudiness': 6.0, 'ceiling': 12192.0, 'pressure': 1017.0, 'precip_1h': 0.0}, {'id': 1, 'time': '2022-09-30T16:58:00+00:00', 'temperature': 16.6, 'humidity': 86.0, 'dew_point': 14.3, 'wind_dir': 315.0, 'wind_spd': 4.4, 'uv_idx': 0.0, 'visibility': 2.0, 'cloudiness': 8.0, 'ceiling': 12192.0, 'pressure': 1017.0, 'precip_1h': 0.0}, {'id': 1, 'time': '2022-09-30T17:57:00+00:00', 'temperature': 16.1, 'humidity': 84.0, 'dew_point': 13.5, 'wind_dir': 315.0, 'wind_spd': 3.0, 'uv_idx': 0.0, 'visibility': 2.0, 'cloudiness': 2.0, 'ceiling': 6096.0, 'pressure': 1017.0, 'precip_1h': 0.0}, {'id': 1, 'time': '2022-09-30T18:04:00+00:00', 'temperature': 15.8, 'humidity': 86.0, 'dew_point': 13.5, 'wind_dir': 315.0, 'wind_spd': 3.0, 'uv_idx': 0.0, 'visibility': 2.0, 'cloudiness': 2.0, 'ceiling': 6096.0, 'pressure': 1015.2, 'preci
# ...

# %%
eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJpOHR2S1FCeEdnNWl2R3VyclVaNU5tIiwiaWF0IjoxNjY3NjQ4MTYyLCJleHAiOjE2Njg3ODM2MDAsInR5cGUiOiJhcGlfa2V5In0.oyQ7W5utmLUK9dzhqHJSi7HTwjJJCs6CYQ9LMzYa4YU
